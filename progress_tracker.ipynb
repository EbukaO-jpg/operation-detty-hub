# %% [markdown]
# <a href="https://colab.research.google.com/github/EbukaO-jpg/operation-detty-hub/blob/main/progress_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- OFFICIAL FITNESS LOG ---
import datetime

daily_stats = {
"date": str(datetime.date.today()),
"weight_kg": 103.3,
"workout_completed": "The Detty Circuit - 3 Rounds",
"skipping_minutes": 15,
"mood_energy": 8, # Scale of 1-10
"adherence": "Pre-dinner workout successful"
}

# This prints your summary so you can see your win for the day
print(f"✅ Logged for {daily_stats['date']}")
print(f"Current Weight: {daily_stats['weight_kg']}kg")
print(f"Goal: 95kg ({daily_stats['weight_kg'] - 95:.1f}kg to go!)")
# Out:
# ✅ Logged for 2026-03-17
# Current Weight: 103.3kg
# Goal: 95kg (8.3kg to go!)
